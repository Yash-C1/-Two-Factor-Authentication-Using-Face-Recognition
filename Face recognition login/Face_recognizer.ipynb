# %%
import cv2
import numpy as np

face_classifier = cv2.CascadeClassifier('Haarcascades/haarcascade_frontalface_default.xml')
samples = []

def face_extractor(img):    
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)
    
    if faces is ():
        return None
    
    # Crop all faces found
    for (x,y,w,h) in faces:
        cropped_face = img[y:y+h, x:x+w]

    return cropped_face

cap = cv2.VideoCapture(0)
count = 0

# Collect 100 samples of your face from webcam input
while True:

    ret, frame = cap.read()
    if face_extractor(frame) is not None:
        count += 1
        face = cv2.resize(face_extractor(frame), (200, 200))
        face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)

        samples.append(np.asarray(face, dtype=np.uint8))

        cv2.putText(face, str(count), (50, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
        cv2.imshow('Face Cropper', face)
        
        
    else:
        print("Face not found")
        pass

    if cv2.waitKey(1) == 13 or count == 100: 
        break
        
cap.release()
cv2.destroyAllWindows()      
print("Collecting Samples Complete")
print(samples)
# Out:
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Face not found
# Collecting Samples Complete
# [array([[58, 56, 57, ..., 49, 50, 50],
#        [57, 56, 56, ..., 49, 50, 50],
#        [57, 57, 56, ..., 49, 49, 49],
#        ...,
#        [51, 51, 51, ..., 33, 34, 32],
#        [51, 50, 51, ..., 35, 33, 33],
#        [50, 49, 51, ..., 35, 26, 32]], dtype=uint8), array([[58, 57, 56, ..., 48, 49, 51],
#        [57, 57, 56, ..., 50, 51, 52],
#        [57, 57, 57, ..., 51, 52, 52],
#        ...,
#        [52, 52, 52, ..., 36, 40, 39],
#        [52, 53, 52, ..., 35, 37, 38],
#        [51, 51, 51, ..., 34, 36, 38]], dtype=uint8), array([[56, 56, 56, ..., 50, 49, 49],
#        [56, 56, 56, ..., 49, 50, 51],
#        [57, 56, 56, ..., 51, 51, 51],
#        ...,
#        [51, 51, 51, ..., 34, 35, 37],
#        [51, 51, 51, ..., 34, 34, 36],
#        [45, 50, 49, ..., 34, 33, 34]], dtype=uint8), array([[57, 57, 58, ..., 48, 51, 52],
#        [56, 56, 56, ..., 51, 51, 52],
#        [56, 54, 52, ..., 52, 52, 52],
#        ...,
#        [52, 51, 48, ..., 34, 34, 34],
#        [48, 49, 49, ..., 35, 34, 33],
#        [48, 49, 50, ..., 35, 34, 33]], dtype=uint8), array([[58, 58, 57, ..., 48, 47, 47],
#        [59, 58, 58, ..., 49, 47, 48],
#        [60, 60, 60, ..., 52, 49, 48],
#        ...,
#        [49, 49, 50, ..., 32, 30, 32],
#        [49, 49, 50, ..., 34, 34, 33],
#        [50, 49, 51, ..., 37, 36, 33]], dtype=uint8), array([[56, 56, 56, ..., 51, 51, 52],
#        [56, 56, 57, ..., 51, 51, 51],
#        [57, 56, 57, ..., 52, 52, 52],
#        ...,
#        [51, 51, 51, ..., 34, 34, 31],
#        [51, 52, 51, ..., 32, 31, 32],
#        [55, 55, 53, ..., 34, 33, 33]], dtype=uint8), array([[59, 56, 56, ..., 52, 52, 52],
#        [61, 57, 57, ..., 51, 50, 51],
#        [60, 58, 58, ..., 51, 51, 51],
#        ...,
#        [49, 51, 52, ..., 34, 30, 31],
#        [50, 52, 50, ..., 33, 33, 33],
#        [51, 52, 50, ..., 33, 33, 34]], dtype=uint8), array([[56, 56, 54, ..., 51, 51, 52],
#        [56, 56, 55, ..., 51, 51, 51],
#        [59, 56, 56, ..., 51, 51, 50],
#        ...,
#        [51, 50, 47, ..., 35, 36, 35],
#        [51, 51, 50, ..., 35, 34, 34],
#        [47, 50, 50, ..., 34, 34, 34]], dtype=uint8), array([[62, 61, 56, ..., 52, 51, 51],
#        [62, 62, 56, ..., 51, 51, 51],
#        [60, 62, 59, ..., 52, 52, 51],
#        ...,
#        [53, 54, 54, ..., 36, 35, 32],
#        [51, 50, 52, ..., 37, 35, 36],
#        [51, 52, 52, ..., 36, 32, 37]], dtype=uint8), array([[57, 56, 56, ..., 51, 51, 51],
#        [57, 57, 57, ..., 51, 51, 50],
#        [60, 55, 58, ..., 53, 51, 48],
#        ...,
#        [55, 53, 51, ..., 34, 33, 33],
#        [52, 52, 52, ..., 34, 34, 34],
#        [52, 52, 52, ..., 35, 34, 34]], dtype=uint8), array([[57, 57, 57, ..., 51, 51, 52],
#        [59, 55, 56, ..., 52, 52, 54],
#        [58, 56, 56, ..., 55, 54, 53],
#        ...,
#        [51, 52, 52, ..., 35, 35, 34],
#        [54, 54, 53, ..., 35, 34, 34],
#        [52, 52, 52, ..., 35, 34, 34]], dtype=uint8), array([[58, 57, 56, ..., 54, 55, 55],
#        [58, 57, 56, ..., 50, 54, 56],
#        [57, 56, 56, ..., 51, 56, 56],
#        ...,
#        [50, 50, 52, ..., 36, 37, 35],
#        [50, 50, 51, ..., 36, 33, 29],
#        [50, 50, 51, ..., 36, 37, 37]], dtype=uint8), array([[44, 27, 13, ..., 54, 54, 54],
#        [44, 27, 12, ..., 54, 55, 55],
#        [38, 29, 16, ..., 56, 56, 56],
#        ...,
#        [48, 50, 50, ..., 41, 37, 37],
#        [47, 48, 47, ..., 42, 42, 41],
#        [46, 47, 44, ..., 43, 43, 41]], dtype=uint8), array([[58, 58, 58, ..., 51, 54, 54],
#        [59, 59, 58, ..., 51, 54, 54],
#        [58, 58, 58, ..., 54, 54, 55],
#        ...,
#        [54, 57, 53, ..., 33, 34, 34],
#        [54, 54, 53, ..., 33, 33, 34],
#        [52, 52, 52, ..., 33, 34, 34]], dtype=uint8), array([[58, 52, 52, ..., 51, 51, 49],
#        [58, 58, 56, ..., 51, 51, 48],
#        [59, 59, 60, ..., 52, 51, 51],
#        ...,
#        [52, 51, 51, ..., 50, 45, 43],
#        [51, 50, 50, ..., 50, 47, 42],
#        [51, 51, 51, ..., 49, 50, 45]], dtype=uint8), array([[57, 56, 55, ..., 52, 51, 51],
#        [57, 56, 56, ..., 51, 52, 50],
#        [59, 57, 57, ..., 51, 51, 50],
#        ...,
#        [52, 52, 51, ..., 41, 38, 38],
#        [53, 52, 52, ..., 43, 40, 39],
#        [52, 52, 49, ..., 44, 41, 40]], dtype=uint8), array([[48, 43, 33, ..., 52, 51, 51],
#        [49, 43, 32, ..., 52, 51, 51],
#        [43, 36, 23, ..., 52, 51, 51],
#        ...,
#        [51, 50, 49, ..., 44, 48, 47],
#        [51, 50, 49, ..., 51, 50, 43],
#        [49, 49, 48, ..., 52, 51, 51]], dtype=uint8), array([[50, 52, 54, ..., 49, 50, 52],
#        [51, 51, 51, ..., 51, 51, 52],
#        [54, 51, 50, ..., 52, 52, 52],
#        ...,
#        [51, 51, 50, ..., 44, 41, 41],
#        [51, 51, 50, ..., 47, 44, 41],
#        [51, 50, 46, ..., 44, 45, 40]], dtype=uint8), array([[52, 52, 56, ..., 50, 49, 50],
#        [52, 52, 55, ..., 51, 50, 51],
#        [51, 51, 52, ..., 53, 52, 52],
#        ...,
#        [48, 48, 48, ..., 43, 41, 38],
#        [48, 51, 51, ..., 43, 41, 40],
#        [48, 47, 47, ..., 49, 43, 40]], dtype=uint8), array([[55, 55, 55, ..., 48, 48, 47],
#        [52, 54, 55, ..., 48, 48, 48],
#        [51, 53, 55, ..., 49, 48, 47],
#        ...,
#        [50, 51, 50, ..., 36, 44, 47],
#        [51, 51, 51, ..., 40, 47, 49],
#        [51, 49, 47, ..., 42, 44, 47]], dtype=uint8), array([[49, 47, 45, ..., 51, 50, 50],
#        [50, 46, 44, ..., 51, 50, 52],
#        [51, 48, 44, ..., 51, 50, 51],
#        ...,
#        [42, 41, 40, ..., 37, 38, 45],
#        [42, 41, 40, ..., 38, 38, 39],
#        [40, 41, 40, ..., 38, 38, 38]], dtype=uint8), array([[54, 55, 54, ..., 52, 52, 51],
#        [52, 52, 54, ..., 52, 52, 54],
#        [51, 50, 52, ..., 52, 52, 52],
#        ...,
#        [40, 40, 39, ..., 38, 38, 40],
#        [44, 43, 41, ..., 38, 38, 37],
#        [41, 43, 41, ..., 37, 37, 37]], dtype=uint8), array([[56, 55, 56, ..., 50, 50, 51],
#        [55, 54, 56, ..., 50, 50, 50],
#        [54, 52, 55, ..., 51, 52, 49],
#        ...,
#        [38, 38, 37, ..., 45, 45, 42],
#        [38, 39, 37, ..., 46, 43, 37],
#        [38, 40, 39, ..., 48, 43, 35]], dtype=uint8), array([[53, 54, 54, ..., 51, 51, 51],
#        [56, 55, 54, ..., 50, 51, 51],
#        [55, 54, 54, ..., 49, 49, 52],
#        ...,
#        [36, 35, 33, ..., 45, 43, 43],
#        [34, 34, 34, ..., 40, 43, 43],
#        [35, 35, 35, ..., 36, 37, 41]], dtype=uint8), array([[55, 55, 55, ..., 51, 50, 51],
#        [54, 51, 54, ..., 51, 50, 49],
#        [53, 53, 53, ..., 52, 51, 50],
#        ...,
#        [34, 32, 32, ..., 41, 41, 46],
#        [35, 34, 33, ..., 42, 41, 47],
#        [35, 34, 33, ..., 41, 39, 38]], dtype=uint8), array([[54, 55, 56, ..., 52, 52, 52],
#        [54, 55, 56, ..., 53, 53, 55],
#        [55, 56, 53, ..., 55, 55, 56],
#        ...,
#        [34, 32, 30, ..., 41, 37, 36],
#        [35, 34, 32, ..., 40, 39, 37],
#        [33, 33, 33, ..., 39, 40, 40]], dtype=uint8), array([[28, 26, 20, ..., 55, 55, 55],
#        [30, 26, 23, ..., 56, 56, 55],
#        [28, 25, 23, ..., 56, 56, 58],
#        ...,
#        [ 3,  1,  2, ..., 45, 43, 43],
#        [ 4,  4,  4, ..., 45, 43, 43],
#        [ 4,  4,  4, ..., 41, 43, 43]], dtype=uint8), array([[48, 46, 48, ..., 53, 52, 51],
#        [47, 48, 50, ..., 54, 52, 52],
#        [49, 50, 49, ..., 54, 52, 52],
#        ...,
#        [ 4,  3,  1, ..., 38, 39, 38],
#        [ 4,  1,  1, ..., 39, 38, 39],
#        [ 4,  2,  1, ..., 41, 42, 40]], dtype=uint8), array([[43, 24, 23, ..., 56, 51, 51],
#        [36, 30, 22, ..., 55, 51, 52],
#        [36, 32, 20, ..., 54, 51, 55],
#        ...,
#        [ 4,  3,  1, ..., 40, 38, 41],
#        [ 2,  1,  1, ..., 37, 37, 44],
#        [ 1,  3,  1, ..., 37, 38, 43]], dtype=uint8), array([[54, 55, 54, ..., 55, 55, 55],
#        [54, 54, 55, ..., 55, 56, 55],
#        [54, 53, 52, ..., 56, 56, 56],
#        ...,
#        [19, 10,  5, ..., 39, 40, 41],
#        [18,  7,  6, ..., 40, 40, 41],
#        [15,  6,  6, ..., 40, 37, 36]], dtype=uint8), array([[50, 50, 50, ..., 56, 55, 55],
#        [50, 50, 50, ..., 56, 55, 55],
#        [50, 51, 51, ..., 56, 55, 55],
#        ...,
#        [ 2,  1,  4, ..., 37, 37, 39],
#        [ 3,  3,  4, ..., 37, 38, 38],
#        [ 4,  4,  4, ..., 36, 38, 40]], dtype=uint8), array([[54, 52, 52, ..., 55, 54, 54],
#        [53, 54, 53, ..., 55, 56, 54],
#        [51, 52, 51, ..., 54, 55, 54],
#        ...,
#        [20, 18,  8, ..., 40, 37, 37],
#        [21, 14,  6, ..., 35, 34, 36],
#        [19, 14,  6, ..., 31, 32, 33]], dtype=uint8), array([[55, 55, 55, ..., 55, 54, 54],
#        [54, 54, 55, ..., 55, 52, 53],
#        [54, 53, 55, ..., 54, 52, 52],
#        ...,
#        [29, 27, 25, ..., 32, 32, 34],
#        [30, 29, 26, ..., 31, 31, 33],
#        [28, 28, 26, ..., 33, 33, 32]], dtype=uint8), array([[54, 52, 53, ..., 51, 53, 55],
#        [54, 53, 55, ..., 52, 52, 54],
#        [53, 53, 54, ..., 54, 54, 54],
#        ...,
#        [25, 25, 25, ..., 41, 41, 40],
#        [27, 27, 25, ..., 43, 41, 35],
#        [32, 27, 26, ..., 43, 37, 34]], dtype=uint8), array([[53, 56, 56, ..., 52, 53, 51],
#        [56, 56, 55, ..., 53, 53, 51],
#        [54, 55, 55, ..., 52, 51, 51],
#        ...,
#        [29, 28, 31, ..., 46, 43, 39],
#        [32, 33, 32, ..., 43, 41, 38],
#        [34, 33, 27, ..., 43, 42, 40]], dtype=uint8), array([[51, 51, 53, ..., 52, 53, 52],
#        [52, 51, 46, ..., 51, 51, 54],
#        [54, 55, 55, ..., 52, 50, 54],
#        ...,
#        [33, 29, 30, ..., 37, 41, 47],
#        [34, 32, 30, ..., 37, 38, 45],
#        [33, 33, 32, ..., 38, 37, 42]], dtype=uint8), array([[51, 52, 52, ..., 51, 51, 51],
#        [51, 51, 51, ..., 51, 52, 52],
#        [52, 51, 51, ..., 52, 54, 54],
#        ...,
#        [31, 31, 29, ..., 47, 48, 49],
#        [31, 31, 29, ..., 43, 45, 48],
#        [31, 30, 27, ..., 41, 46, 44]], dtype=uint8), array([[55, 54, 53, ..., 55, 52, 50],
#        [56, 55, 55, ..., 54, 55, 54],
#        [54, 57, 55, ..., 53, 54, 54],
#        ...,
#        [37, 36, 36, ..., 37, 36, 35],
#        [37, 36, 35, ..., 37, 35, 34],
#        [37, 36, 35, ..., 35, 34, 33]], dtype=uint8), array([[54, 53, 52, ..., 54, 52, 48],
#        [53, 52, 52, ..., 55, 55, 54],
#        [52, 52, 52, ..., 55, 55, 54],
#        ...,
#        [37, 36, 35, ..., 37, 37, 36],
#        [39, 36, 36, ..., 39, 37, 36],
#        [37, 36, 35, ..., 40, 38, 37]], dtype=uint8), array([[56, 55, 52, ..., 51, 50, 51],
#        [56, 54, 52, ..., 51, 46, 51],
#        [55, 51, 53, ..., 51, 48, 52],
#        ...,
#        [39, 44, 38, ..., 37, 37, 37],
#        [38, 41, 40, ..., 38, 37, 37],
#        [40, 40, 40, ..., 38, 37, 37]], dtype=uint8), array([[53, 52, 54, ..., 52, 51, 51],
#        [51, 51, 51, ..., 53, 52, 51],
#        [51, 51, 51, ..., 52, 51, 51],
#        ...,
#        [37, 37, 37, ..., 39, 39, 37],
#        [37, 37, 37, ..., 42, 41, 39],
#        [37, 37, 39, ..., 43, 41, 42]], dtype=uint8), array([[51, 51, 51, ..., 53, 52, 51],
#        [52, 51, 51, ..., 52, 52, 52],
#        [54, 51, 52, ..., 52, 52, 52],
#        ...,
#        [42, 42, 41, ..., 41, 39, 36],
#        [43, 42, 40, ..., 40, 38, 37],
#        [42, 41, 39, ..., 38, 38, 36]], dtype=uint8), array([[49, 53, 50, ..., 51, 52, 55],
#        [52, 54, 51, ..., 51, 53, 54],
#        [52, 53, 53, ..., 52, 52, 53],
#        ...,
#        [37, 36, 36, ..., 42, 42, 43],
#        [37, 36, 36, ..., 42, 43, 43],
#        [38, 36, 37, ..., 44, 43, 43]], dtype=uint8), array([[45, 45, 37, ..., 55, 56, 56],
#        [47, 44, 36, ..., 56, 56, 58],
#        [47, 39, 28, ..., 56, 56, 61],
#        ...,
#        [35, 34, 31, ..., 36, 40, 40],
#        [35, 35, 33, ..., 35, 36, 40],
#        [35, 35, 35, ..., 35, 37, 38]], dtype=uint8), array([[53, 52, 51, ..., 56, 54, 54],
#        [52, 52, 51, ..., 55, 53, 53],
#        [51, 50, 49, ..., 54, 55, 53],
#        ...,
#        [36, 35, 35, ..., 40, 41, 42],
#        [36, 36, 35, ..., 41, 42, 42],
#        [36, 37, 43, ..., 44, 43, 43]], dtype=uint8), array([[52, 50, 49, ..., 52, 54, 55],
#        [51, 50, 48, ..., 52, 51, 54],
#        [51, 51, 50, ..., 52, 51, 51],
#        ...,
#        [38, 36, 36, ..., 40, 41, 41],
#        [36, 37, 36, ..., 39, 41, 42],
#        [36, 36, 36, ..., 37, 40, 41]], dtype=uint8), array([[52, 50, 50, ..., 53, 55, 55],
#        [51, 50, 48, ..., 55, 55, 51],
#        [50, 50, 48, ..., 55, 53, 52],
#        ...,
#        [37, 37, 36, ..., 38, 36, 46],
#        [39, 37, 35, ..., 40, 35, 39],
#        [40, 36, 36, ..., 45, 38, 38]], dtype=uint8), array([[50, 50, 46, ..., 53, 51, 57],
#        [49, 44, 46, ..., 56, 55, 54],
#        [43, 43, 40, ..., 56, 56, 55],
#        ...,
#        [36, 36, 35, ..., 40, 38, 40],
#        [36, 35, 35, ..., 39, 40, 38],
#        [37, 36, 34, ..., 42, 38, 38]], dtype=uint8), array([[21, 20, 14, ..., 56, 56, 56],
#        [24, 21, 18, ..., 56, 56, 56],
#        [21, 21, 20, ..., 55, 56, 56],
#        ...,
#        [36, 34, 33, ..., 34, 35, 38],
#        [35, 31, 31, ..., 34, 34, 36],
#        [33, 33, 31, ..., 40, 34, 37]], dtype=uint8), array([[50, 49, 45, ..., 55, 54, 52],
#        [50, 48, 44, ..., 55, 55, 55],
#        [50, 46, 42, ..., 55, 55, 55],
#        ...,
#        [38, 37, 36, ..., 34, 38, 37],
#        [37, 39, 37, ..., 35, 40, 41],
#        [40, 40, 37, ..., 41, 43, 45]], dtype=uint8), array([[19, 16, 14, ..., 54, 54, 54],
#        [21, 20, 14, ..., 56, 55, 54],
#        [21, 21, 14, ..., 55, 54, 52],
#        ...,
#        [31, 31, 29, ..., 35, 36, 42],
#        [33, 33, 28, ..., 35, 35, 41],
#        [33, 33, 31, ..., 34, 35, 36]], dtype=uint8), array([[53, 53, 52, ..., 54, 52, 52],
#        [48, 53, 52, ..., 55, 55, 54],
#        [50, 53, 53, ..., 56, 57, 55],
#        ...,
#        [48, 42, 39, ..., 39, 42, 42],
#        [45, 41, 40, ..., 45, 44, 44],
#        [42, 36, 41, ..., 44, 44, 44]], dtype=uint8), array([[54, 55, 53, ..., 55, 55, 51],
#        [54, 54, 54, ..., 55, 54, 52],
#        [53, 52, 54, ..., 54, 55, 54],
#        ...,
#        [49, 47, 45, ..., 45, 47, 43],
#        [46, 45, 45, ..., 44, 43, 41],
#        [45, 45, 46, ..., 43, 41, 40]], dtype=uint8), array([[56, 56, 55, ..., 52, 51, 50],
#        [54, 54, 55, ..., 53, 51, 50],
#        [51, 53, 55, ..., 53, 51, 50],
#        ...,
#        [44, 43, 43, ..., 39, 40, 45],
#        [43, 42, 41, ..., 42, 40, 47],
#        [45, 44, 44, ..., 43, 41, 46]], dtype=uint8), array([[52, 53, 55, ..., 51, 51, 52],
#        [52, 52, 54, ..., 51, 51, 51],
#        [53, 51, 53, ..., 50, 50, 50],
#        ...,
#        [48, 47, 46, ..., 43, 41, 40],
#        [48, 47, 43, ..., 40, 38, 38],
#        [49, 46, 42, ..., 37, 36, 36]], dtype=uint8), array([[52, 54, 49, ..., 51, 53, 54],
#        [54, 50, 51, ..., 50, 50, 52],
#        [49, 49, 51, ..., 51, 51, 51],
#        ...,
#        [43, 39, 41, ..., 47, 43, 43],
#        [45, 43, 42, ..., 50, 50, 44],
#        [45, 43, 43, ..., 50, 51, 45]], dtype=uint8), array([[18, 18, 17, ..., 54, 54, 55],
#        [17, 16, 16, ..., 56, 54, 54],
#        [16, 16, 15, ..., 58, 55, 54],
#        ...,
#        [36, 36, 36, ..., 38, 38, 34],
#        [35, 35, 36, ..., 36, 36, 35],
#        [34, 35, 35, ..., 35, 35, 36]], dtype=uint8), array([[48, 46, 48, ..., 55, 55, 55],
#        [48, 49, 48, ..., 54, 56, 56],
#        [49, 48, 49, ..., 55, 56, 56],
#        ...,
#        [42, 42, 41, ..., 41, 40, 39],
#        [43, 43, 41, ..., 46, 43, 40],
#        [43, 42, 40, ..., 51, 52, 41]], dtype=uint8), array([[55, 54, 54, ..., 51, 52, 52],
#        [51, 50, 49, ..., 53, 54, 54],
#        [51, 51, 50, ..., 55, 56, 55],
#        ...,
#        [49, 46, 42, ..., 51, 48, 48],
#        [46, 46, 42, ..., 48, 48, 48],
#        [45, 44, 41, ..., 48, 49, 49]], dtype=uint8), array([[51, 52, 53, ..., 52, 50, 48],
#        [50, 52, 54, ..., 52, 52, 51],
#        [51, 52, 52, ..., 52, 52, 52],
#        ...,
#        [44, 44, 43, ..., 44, 43, 44],
#        [45, 44, 43, ..., 47, 45, 45],
#        [45, 46, 44, ..., 49, 47, 43]], dtype=uint8), array([[48, 44, 33, ..., 51, 51, 50],
#        [40, 36, 26, ..., 52, 51, 50],
#        [41, 33, 23, ..., 53, 52, 52],
#        ...,
#        [41, 42, 41, ..., 38, 40, 42],
#        [41, 41, 41, ..., 39, 42, 43],
#        [41, 41, 41, ..., 37, 40, 43]], dtype=uint8), array([[50, 51, 48, ..., 49, 49, 52],
#        [52, 52, 50, ..., 49, 49, 52],
#        [53, 52, 52, ..., 51, 50, 53],
#        ...,
#        [46, 43, 42, ..., 38, 43, 43],
#        [48, 46, 43, ..., 42, 46, 48],
#        [48, 45, 43, ..., 46, 47, 48]], dtype=uint8), array([[49, 52, 51, ..., 51, 52, 54],
#        [51, 52, 52, ..., 52, 52, 51],
#        [51, 51, 51, ..., 52, 52, 50],
#        ...,
#        [44, 45, 44, ..., 43, 45, 47],
#        [44, 44, 43, ..., 40, 43, 47],
#        [48, 46, 44, ..., 40, 40, 44]], dtype=uint8), array([[55, 53, 51, ..., 55, 55, 54],
#        [53, 52, 49, ..., 55, 55, 54],
#        [50, 50, 50, ..., 55, 55, 54],
#        ...,
#        [44, 44, 45, ..., 49, 43, 38],
#        [45, 48, 47, ..., 50, 47, 42],
#        [47, 50, 48, ..., 51, 49, 43]], dtype=uint8), array([[55, 55, 55, ..., 49, 48, 47],
#        [52, 54, 55, ..., 50, 48, 44],
#        [52, 54, 55, ..., 51, 50, 45],
#        ...,
#        [49, 48, 46, ..., 50, 49, 49],
#        [49, 49, 48, ..., 50, 47, 45],
#        [50, 49, 48, ..., 53, 45, 43]], dtype=uint8), array([[50, 50, 51, ..., 53, 52, 54],
#        [49, 50, 50, ..., 56, 55, 52],
#        [50, 50, 50, ..., 54, 52, 51],
#        ...,
#        [46, 44, 44, ..., 36, 35, 36],
#        [47, 45, 43, ..., 37, 36, 39],
#        [45, 40, 41, ..., 37, 37, 41]], dtype=uint8), array([[49, 50, 50, ..., 54, 55, 55],
#        [50, 50, 50, ..., 55, 56, 55],
#        [49, 51, 50, ..., 55, 55, 55],
#        ...,
#        [44, 44, 44, ..., 41, 40, 40],
#        [43, 43, 44, ..., 42, 40, 40],
#        [43, 44, 45, ..., 41, 40, 38]], dtype=uint8), array([[51, 51, 50, ..., 50, 51, 51],
#        [50, 50, 51, ..., 50, 51, 52],
#        [51, 50, 51, ..., 51, 52, 52],
#        ...,
#        [45, 45, 48, ..., 40, 40, 40],
#        [45, 46, 46, ..., 38, 38, 37],
#        [47, 46, 45, ..., 38, 38, 38]], dtype=uint8), array([[49, 48, 48, ..., 54, 52, 54],
#        [47, 46, 47, ..., 56, 55, 55],
#        [46, 45, 43, ..., 56, 55, 54],
#        ...,
#        [48, 48, 42, ..., 47, 45, 44],
#        [44, 44, 42, ..., 45, 45, 39],
#        [47, 45, 43, ..., 44, 47, 38]], dtype=uint8), array([[52, 52, 49, ..., 51, 49, 51],
#        [51, 49, 47, ..., 52, 49, 54],
#        [50, 50, 50, ..., 52, 53, 55],
#        ...,
#        [44, 44, 45, ..., 36, 29, 40],
#        [43, 45, 44, ..., 37, 28, 41],
#        [44, 43, 44, ..., 38, 33, 40]], dtype=uint8), array([[50, 49, 49, ..., 54, 54, 54],
#        [50, 49, 48, ..., 52, 52, 54],
#        [48, 50, 45, ..., 52, 52, 54],
#        ...,
#        [44, 43, 38, ..., 40, 38, 38],
#        [44, 42, 37, ..., 38, 38, 37],
#        [43, 40, 37, ..., 38, 37, 38]], dtype=uint8), array([[51, 51, 50, ..., 56, 56, 56],
#        [51, 51, 51, ..., 55, 55, 55],
#        [50, 50, 50, ..., 54, 54, 55],
#        ...,
#        [44, 44, 42, ..., 37, 36, 36],
#        [44, 43, 42, ..., 37, 41, 37],
#        [44, 42, 43, ..., 37, 36, 36]], dtype=uint8), array([[46, 48, 42, ..., 51, 54, 54],
#        [47, 48, 44, ..., 54, 54, 54],
#        [43, 46, 40, ..., 54, 54, 52],
#        ...,
#        [42, 41, 42, ..., 41, 40, 40],
#        [42, 42, 41, ..., 42, 41, 40],
#        [40, 41, 41, ..., 42, 41, 43]], dtype=uint8), array([[49, 50, 47, ..., 53, 51, 52],
#        [49, 50, 49, ..., 54, 53, 56],
#        [52, 51, 52, ..., 56, 55, 56],
#        ...,
#        [42, 43, 41, ..., 37, 37, 38],
#        [44, 40, 38, ..., 37, 37, 38],
#        [43, 41, 42, ..., 40, 37, 37]], dtype=uint8), array([[55, 50, 50, ..., 51, 51, 51],
#        [55, 55, 54, ..., 51, 51, 51],
#        [54, 55, 54, ..., 52, 51, 51],
#        ...,
#        [43, 42, 42, ..., 43, 43, 44],
#        [42, 42, 43, ..., 44, 42, 42],
#        [43, 42, 42, ..., 45, 42, 37]], dtype=uint8), array([[52, 52, 51, ..., 50, 52, 52],
#        [52, 51, 51, ..., 51, 50, 52],
#        [52, 53, 51, ..., 53, 52, 54],
#        ...,
#        [42, 40, 39, ..., 43, 42, 36],
#        [41, 41, 41, ..., 49, 46, 36],
#        [39, 40, 40, ..., 50, 50, 38]], dtype=uint8), array([[54, 51, 50, ..., 51, 52, 52],
#        [53, 51, 49, ..., 53, 52, 52],
#        [51, 51, 51, ..., 52, 50, 52],
#        ...,
#        [42, 43, 42, ..., 48, 41, 38],
#        [41, 39, 38, ..., 49, 42, 38],
#        [40, 38, 37, ..., 48, 43, 37]], dtype=uint8), array([[16, 16, 17, ..., 56, 56, 52],
#        [16, 16, 23, ..., 56, 54, 54],
#        [16, 15, 21, ..., 56, 55, 55],
#        ...,
#        [34, 34, 34, ..., 46, 47, 43],
#        [34, 34, 34, ..., 37, 37, 37],
#        [36, 34, 34, ..., 36, 37, 37]], dtype=uint8)]
